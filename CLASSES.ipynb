# %%
class BaseSalary:
  def __init__(self, base_salary, bonus_rate = 0.1, symbol = "$"):
    self.base_salary = base_salary
    self.bonus_rate = bonus_rate
    self.symbol = symbol
    self.total_salary = base_salary * ( 1 + bonus_rate)
    self.bonus = (self.total_salary - base_salary)/ base_salary # alaways use camel for class name

  def __repr__(self):
    return f'{self.symbol}{self.base_salary:,.0f}'

# %%
salary = BaseSalary(100000,  .2)

salary

# %%
salary = BaseSalary(100000, .2)

salary

# %%
value = 10000

f'{value :,.0f}'
# Out:
# '10,000.00'
